# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import glob
import sys
import time
from copy import deepcopy

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# The purpose of the following cell is to list all the available economic indicators that we will use as features in our modeling.

# %%
indicatorIdxs = []
for indicator_file in glob.glob("Data/Economic indicators/*"):
    print(indicator_file)
    indi_cols = list(pd.read_csv(indicator_file).columns)
    if indi_cols.index('Value'):
        indicatorIdxs.append(indi_cols.index('Value'))
    else:
        sys.exit(0)
    print(indi_cols, end="\n"+"-"*len(str(indi_cols))+"\n")
print("Num Indicators:", len(indicatorIdxs))
# Out:
# Data/Economic indicators/historical_country_United_States_indicator_API_Product_Imports.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Manufacturing.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Private_Debt_to_GDP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Pending_Home_Sales.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Crude_Oil_Rigs.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Crude_Oil_Imports.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Wages_in_Manufacturing.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Balance_of_Trade.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Wage_Growth.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Net_Long_Term_Tic_Flows.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Core_Producer_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Foreign_Direct_Investment.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Producer_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Core_Inflation_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Cpi_Median.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Average_Hourly_Earnings.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Retail_Sales_MoM.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Redbook_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_ADP_Employment_Change.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Leading_Economic_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Corporate_Tax_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Grain_Stocks_Corn.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Cpi_Core_Core.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Average_Weekly_Hours.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Core_Consumer_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Car_Production.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Unemployed_Persons.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Pce_Price_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Business_Confidence.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Case_Shiller_Home_Price_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Coronavirus_Vaccination_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Agriculture.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Nonfarm_Payrolls_Private.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Terrorism_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Dallas_Fed_Manufacturing_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Imports.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Total_Vehicle_Sales.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Mining_Production.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Core_Pce_Price_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Inflation_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Long_Term_Unemployment_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Tourism_Revenues.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Distillate_Stocks.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Consumer_Credit.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Utilities.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Corruption_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Gross_Fixed_Capital_Formation.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Challenger_Job_Cuts.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Loans_to_Private_Sector.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Interbank_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Personal_Income.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Mortgage_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Spending.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Consumer_Price_Index_CPI.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Banks_Balance_Sheet.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Economic_Optimism_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Exports.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Capacity_Utilization.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Oil_Exports.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Corporate_Profits.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Gasoline_Stocks.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Currency.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Current_Account_to_GDP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Gasoline_Production.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_CPI_Housing_Utilities.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Nurses.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Consumer_Spending.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Lmi_Inventory_Costs_.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Cpi_Trimmed_mean.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Industrial_Production.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Goods_Trade_Balance.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Retirement_Age_Women.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Corruption_Rank.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Durable_Goods_Orders.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Bankruptcies.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Heating_Oil.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Non_Farm_Payrolls.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Unemployment_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Net_Long_Term_Tic_Flows (1).csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Housing_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Fiscal_Expenditure.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Construction.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Current_Account.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Distillate_Stocks.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Factory_Orders.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_per_capita.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Producer_Prices_Change.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_Deflator.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Changes_in_Inventories.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Personal_Savings.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_New_Home_Sales.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Wholesale_Inventories.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Business_Inventories.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_CPI_Transportation.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Budget_Value.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Job_Vacancies.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Public_Administration.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Coronavirus_Cases.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Transport.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Inflation_Expectations.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Asylum_Applications.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Debt_to_GDP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Gasoline_Stocks_Change.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Coronavirus_Recovered.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Hospitals.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Competitiveness_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Home_Ownership_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Lmi_Logistics_Managers_Index_Current.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Pandemic_Unemployment_Assistance_Claims.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Productivity.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_Annual_Growth_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Full_Time_Employment.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Private_Sector_Credit.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Export_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Revenues.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Inflation_Rate_Mom.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Gasoline_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Car_Registrations.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Continuing_Jobless_Claims.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Jobless_Claims_4_week_Average.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Labor_Force_Participation_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Cushing_Crude_Oil_Stocks.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Crude_Oil_Stocks_Change.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Employment_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Crude_Oil_Stock_Change.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Labour_Costs.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Households_Debt_To_GDP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Tourist_Arrivals.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Employed_Persons.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Money_Supply_M2.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Nahb_Housing_Market_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Coronavirus_Deaths.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Foreign_Bond_Investment.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Ease_of_Doing_Business.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Retail_Sales_YoY.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Mortgage_Applications.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Money_Supply_M0.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Central_Bank_Balance_Sheet.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Single_Family_Home_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Minimum_Wages.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Money_Supply_M1.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Employment_Cost_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Competitiveness_Rank.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Cushing_Number.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Crude_Runs.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Terms_of_Trade.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Hospital_Beds.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Manufacturing_Payrolls.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Wages.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Job_Offers.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_External_Debt.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Disposable_Personal_Income.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Spending_To_GDP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Part_Time_Employment.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Personal_Income_Tax_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Existing_Home_Sales.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Retail_Sales_Ex_Autos.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Retirement_Age_Men.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Food_Inflation.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Youth_Unemployment_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Services.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Weapons_Sales.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_Constant_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Coronavirus_Vaccination_Total.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Gold_Reserves.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Interest_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Capital_Flows.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Initial_Jobless_Claims.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Medical_Doctors.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Consumer_Confidence.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Construction_Spending.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Import_Prices.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_API_Crude_Imports.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Payrolls.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_per_capita_PPP.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Budget.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Foreign_Exchange_Reserves.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Crude_Oil_Production.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Military_Expenditure.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Stock_Market.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Building_Permits.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Gross_National_Product.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Distillate_Fuel_Production.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Debt.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_GDP_From_Mining.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Chicago_Fed_National_Activity_Index.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Repo_Rate.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Housing_Starts.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Chain_Store_Sales.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Population.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Data/Economic indicators/historical_country_United_States_indicator_Government_Bond_10Y.csv
# ['Country', 'Category', 'DateTime', 'Value', 'Frequency', 'HistoricalDataSymbol', 'LastUpdate']
# -----------------------------------------------------------------------------------------------
# Num Indicators: 192

# %% [markdown]
# # Functions

# %%
months = {"JAN":1, "FEB":2, "MAR":3, "APR":4, "MAY":5, "JUN":6, 
          "JUL":7, "AUG":8, "SEP":9, "OCT":10, "NOV":11, "DEC":12}

# %%
def add_dates(dataframe, startYear, endYear, startMonth, endMonth):
    """
    Create Dense neural network model for evaluating each indicator's explanatory strength
    
    inputs
    --
    dataframe (pd.DataFrame())
    startYear (int) : starting year of the data (ex. 2009)
    endYear (int) : ending year of the data (ex. 2021)
    startMonth (int) : index of the month (1 is january, 12 is december)
    endMonth (int) :  index of the month (1 is january, 12 is december)
    
    
    outputs
    --
    modified dataframe
    """
    
#     if "Month" and "Year" in dataframe.columns:
#         dataframe["Indicator"] = 0
#         return dataframe
    
    # Initialize lists for new columns in DataFrame
    columnMonth = []
    columnYear = []
    columnIndicator = []
    # Append year, month, and empty indicator values for each remaining month in the first year
    for p in range(startMonth, 13):
        columnMonth.append(p)
        columnYear.append(startYear)
        columnIndicator.append(0)
    # Append year, month, and empty indicator value for each month in the remaining years (besides the last)
    for x in range(startYear + 1, endYear):
        for i in range(1, 13):
            columnMonth.append(i)
            columnYear.append(x)
            columnIndicator.append(0)
    # Append year, month, and empty indicator value for the remaining months in the last year
    for r in range(1, endMonth + 1):
        columnMonth.append(r)
        columnYear.append(endYear)
        columnIndicator.append(0)
    # Add the year, month, and empty indicator columns to the original dataset
    dataframe['Year'] = columnYear
    dataframe['Month'] = columnMonth
    dataframe['Indicator'] = columnIndicator
    return dataframe

# %%
def create_model(numNodes, includeIndicator, activation='relu',
                 optimizer='adam', loss='mean_squared_error'):
    """
    Create Dense neural network model for evaluating each indicator's explanatory strength
    
    inputs
    --
    numNodes (int) : baseline number of nodes used for constructing the neural network layers
    includeIndicator (bool) : Used to mark whether a model is fitted with an indicator feature
    activation, optimizer, loss (string) : Tensorflow neural network parameters
    
    outputs
    --
    model (tf.keras.Model()) : neural network model
    """
    
    
    model = Sequential()
    model.add(Dense(numNodes*5/3, activation = activation, input_dim=2+int(includeIndicator))) # increase input_dim
#     model.add(Dense(numNodes*2/3, activation = activation))
    model.add(Dropout(0.2))
    model.add(Dense(numNodes*1/3, activation = activation))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'linear'))
    model.compile(optimizer=optimizer, loss=loss)
    return model

# TODO: add parameters for input size, num layers, etc.
def train_and_test(dataframe, trainYears, testYear, indexOfIndicator, 
                   indicatorData, numNodes, SalesColName, includeIndicator):
    """
    Train and test neural network on data
    
    inputs
    --
    dataframe (pd.DataFrame()) : dataset used for inputs into model
    trainYears : used for assigning training/testing partitions
    testYear : used for assigning training/testing partitions
    indexOfIndicator (int) : the index of the indicator value
    indicatorData : DataFrame/Series of indicator values for each time period
    numNodes (int) : baseline number of nodes used for constructing the neural network layers
    SalesColName (string) : the name of the sales column used by the dataframe parameter variable
    includeIndicator (bool) : Used to mark whether a model is fitted with an indicator feature
    
    outputs
    --
    trainStDev (float) : standard deviation of the training data
    testRMSE : root mean squared error of the model predictions
    """
    
    # dataframe with an index 0 to length - 1, sales as the first column, followed by year, and month
    # not optimized for multiple indicators yet, will continue updating for multiple indicator
    if includeIndicator:
        features = ['Sales', 'Year', 'Month', 'Indicator']
        IndicatorValues = indicatorData.iloc[:, indexOfIndicator]
        dataframe['Indicator'] = IndicatorValues
    else:
        features = ['Sales', 'Year', 'Month']
    
    # preprocess training data
    dataframe["Sales"] = dataframe[SalesColName]
    if SalesColName != "Sales":
        dataframe = dataframe.drop(SalesColName, axis=1)
    
    # assign testing data
    testData = dataframe.loc[dataframe['Year'] == testYear]
    testData = testData.reset_index()
    testData = testData[features] # add 'UnemploymentRateValues'
    
    # assign training data
    trainYearIdx = dataframe['Year'].apply(lambda x: any([x==ty for ty in trainYears]))
    trainData = dataframe.loc[trainYearIdx]
    trainData = trainData.reset_index()
    trainData = trainData[features] # add 'UnemploymentRateValues'
    
    # Isolate training and test sets
    X = trainData.iloc[:, 1:3+int(includeIndicator)] # increase index
    Y = trainData.iloc[:, 0]
    
    Xi_Test = testData.iloc[:, 1:3+int(includeIndicator)] # increase index
    Yi_Test = testData.iloc[:, 0]
    XTrain, XTest, YTrain, YTest = train_test_split(X, Y, test_size = 0.2, shuffle = True)

    # Create and Fit Model
    model = create_model(numNodes, includeIndicator)
    model.fit(XTrain, YTrain, epochs=100, batch_size=128, verbose=0) #change batch size to a variable
    
    # Test results from model using training data
    YPreds = model.predict(XTest)
    try:
        testRMSE = mean_squared_error(YTest, YPreds, squared=False)
        trainStDev = trainData['Sales'].std()
    except:
        return np.nan, np.nan
    return trainStDev, testRMSE

# %%
def run_pipeline(data, indicatorData, indexOfIndicator, salesColumn, trainYears, testYear, 
                 numNodes, startYear, endYear, startMonth, endMonth, includeIndicator):
    
    """
    parameters are a combination of the add_dates() and train_and_test()
    """
    dataNew = pd.DataFrame(data)
    # specify your sales column. New is my sales in this case #5
    if "Month" not in dataNew and "Year" not in dataNew:
        dataNew = dataNew[[salesColumn]]
        # specify start year, end year, start month, end month
        dataNew = add_dates(dataNew, startYear, endYear, startMonth, endMonth)
    else:
        dataNew = dataNew[[salesColumn, "Month", "Year"]]
    #the data now has 3 columns: Sales, Month, Year, indicator (all 0s won't make a difference)
    StDev, testRMSE = train_and_test(dataNew, trainYears, testYear,
                                     indexOfIndicator, indicatorData, 
                                     numNodes, salesColumn, includeIndicator)
    return StDev, testRMSE

# %% [markdown]
# ### Feature engineering ideas
#     - inverse years from current year (years closer to test year should be weighted more heavily)
#     - one-hot encoded month and possibly day

# %% [markdown]
# # Testing

# %% [markdown]
# ## Costco Dataset

# %%
Costco_Monthly = pd.read_csv("Data/Costco_Monthly Sales from 2012 to 2021.csv", header=0)
Costco_Monthly["Day"] = Costco_Monthly.Date.apply(lambda x: int(x.split("-")[0]))
Costco_Monthly = Costco_Monthly.drop(["Date"], axis=1)
Costco_Monthly = Costco_Monthly.dropna()
Costco_Monthly
# Out:
#      Month  Year  Net Sales (billions) Growth Rate  Day
# 0        1  2012                  7.00         11%   12
# 2        3  2012                  9.13         10%   12
# 3        4  2012                  7.25          7%   12
# 4        5  2012                  7.67          7%   12
# 5        6  2012                  9.18          6%   12
# ..     ...   ...                   ...         ...  ...
# 109      2  2021                 14.05         15%   21
# 110      3  2021                 18.21         18%   21
# 111      4  2021                 15.21         34%   21
# 112      5  2021                 15.59         24%   21
# 113      6  2021                 18.92         17%   21
#
# [113 rows x 5 columns]

# %%
numNodes = 153 # approx 2/3 of the number of your rows. Make this divisible by a three #6
start = time.time()
SalesColName = "Net Sales (billions)"
TestYears = [2018, 2019, 2020]
startYear = 2002 # 7
endYear = 2021 # 8
startMonth = 1 # 9
endMonth = 4 # 10

# %% [markdown]
# # With Indicator

# %%
includeIndicator = True
resultsCostco = pd.DataFrame()

# %% [markdown]
# Loops through all the economic indicators and for each one, trains a model and evaluates its explained variance ratio.

# %%
Costco_Monthly
# Out:
#      Month  Year  Net Sales (billions) Growth Rate  Day
# 0        1  2012                  7.00         11%   12
# 2        3  2012                  9.13         10%   12
# 3        4  2012                  7.25          7%   12
# 4        5  2012                  7.67          7%   12
# 5        6  2012                  9.18          6%   12
# ..     ...   ...                   ...         ...  ...
# 109      2  2021                 14.05         15%   21
# 110      3  2021                 18.21         18%   21
# 111      4  2021                 15.21         34%   21
# 112      5  2021                 15.59         24%   21
# 113      6  2021                 18.92         17%   21
#
# [113 rows x 5 columns]

# %%
for i, indicator_file in enumerate(glob.glob("Data/Economic indicators/*")):
    print(i+1, "_".join(indicator_file.split("/")[-1].split("_")[5:])[:-4])
    indexOfIndicator = indicatorIdxs[i]
    indicatorData = pd.read_csv(indicator_file)
    for TestYear in TestYears:
        TrainYears = list(range(startYear,TestYear))
        trainStDev, testRMSE = train_and_test(Costco_Monthly, TrainYears, TestYear, indexOfIndicator, 
                                              indicatorData, numNodes, SalesColName, includeIndicator)
        currResults = {
            "Train Years": f"[{TrainYears[0]} ... {TrainYears[-1]}]",
            "Pred Year": int(TestYear),
            "Indicator": indicator_file.split("/")[-1],
            "Train StDev": round(trainStDev, 3), 
            "Test RMSE": round(testRMSE, 3),
            "Explained Variance Ratio": round((trainStDev - testRMSE) / trainStDev, 3)
        }
        resultsCostco = resultsCostco.append(currResults, ignore_index=True)

print("Time elapsed:", time.time()-start)            
resultsCostco.head()
# Out:
# 1 API_Product_Imports
# 2021-12-05 10:24:43.680036: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-05 10:24:44.051896: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2 GDP_From_Manufacturing
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8407e55ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8407848af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3 Private_Debt_to_GDP
# 4 Pending_Home_Sales
# 5 Crude_Oil_Rigs
# 6 Crude_Oil_Imports
# 7 Wages_in_Manufacturing
# 8 Balance_of_Trade
# 9 Wage_Growth
# 10 Net_Long_Term_Tic_Flows
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/44440614.py in <module>
#       6     for TestYear in TestYears:
#       7         TrainYears = list(range(startYear,TestYear))
# ----> 8         trainStDev, testRMSE = train_and_test(Costco_Monthly, TrainYears, TestYear, indexOfIndicator,
#       9                                               indicatorData, numNodes, SalesColName, includeIndicator)
#      10         currResults = {
#
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/445825958.py in train_and_test(dataframe, trainYears, testYear, indexOfIndicator, indicatorData, numNodes, SalesColName, includeIndicator, skipPreprocessing)
#      84     # Create and Fit Model
#      85     model = create_model(numNodes, includeIndicator)
# ---> 86     model.fit(XTrain, YTrain, epochs=100, batch_size=128, verbose=0) #change batch size to a variable
#      87
#      88     # Test results from model using training data
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1191                 _r=1):
#    1192               callbacks.on_train_batch_begin(step)
# -> 1193               tmp_logs = self.train_function(iterator)
#    1194               if data_handler.should_sync:
#    1195                 context.async_wait()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
resultsCostco.sort_values(by="Explained Variance Ratio").head(15)
# Out:
#          Train Years  Pred Year  \
# 669  [2002 ... 2018]     2019.0
# 670  [2002 ... 2019]     2020.0
# 668  [2002 ... 2017]     2018.0
# 562  [2002 ... 2019]     2020.0
# 560  [2002 ... 2017]     2018.0
# 561  [2002 ... 2018]     2019.0
# 629  [2002 ... 2017]     2018.0
# 729  [2002 ... 2018]     2019.0
# 728  [2002 ... 2017]     2018.0
# 587  [2002 ... 2017]     2018.0
# 591  [2002 ... 2018]     2019.0
# 565  [2002 ... 2019]     2020.0
# 574  [2002 ... 2019]     2020.0
# 212  [2002 ... 2017]     2018.0
# 730  [2002 ... 2019]     2020.0
#
#                                              Indicator  Train StDev  \
# 669  historical_country_United_States_indicator_Cor...        1.811
# 670  historical_country_United_States_indicator_Cor...        2.062
# 668  historical_country_United_States_indicator_Cor...        1.555
# 562  historical_country_United_States_indicator_Tou...        2.062
# 560  historical_country_United_States_indicator_Tou...        1.555
# 561  historical_country_United_States_indicator_Tou...        1.811
# 629  historical_country_United_States_indicator_Ext...        1.555
# 729  historical_country_United_States_indicator_Gov...        1.811
# 728  historical_country_United_States_indicator_Gov...        1.555
# 587  historical_country_United_States_indicator_Mon...        1.555
# 591  historical_country_United_States_indicator_Cen...        1.811
# 565  historical_country_United_States_indicator_Emp...        2.062
# 574  historical_country_United_States_indicator_Cor...        2.062
# 212  historical_country_United_States_indicator_For...        1.555
# 730  historical_country_United_States_indicator_Gov...        2.062
#
#      Test RMSE  Explained Variance Ratio
# 669  64539.118                -35644.429
# 670  60357.003                -29268.046
# 668  13474.930                 -8662.961
# 562  12682.064                 -6148.940
# 560   5949.237                 -3824.174
# 561   2419.059                 -1335.064
# 629   1988.275                 -1277.399
# 729    689.150                  -379.622
# 728    577.127                  -370.074
# 587    376.572                  -241.124
# 591    423.913                  -233.131
# 565    356.275                  -171.769
# 574    315.598                  -152.043
# 212    225.279                  -143.847
# 730    233.130                  -112.052

# %%
resultsCostco.to_csv("Results/resultsCostco.csv")
resultsCostco.sort_values(by="Explained Variance Ratio").to_csv("Results/resultsCostco_sorted.csv")

# %% [markdown]
# # Without Indicator

# %%
includeIndicator = False
SalesColName = "Net Sales (billions)"
resultsCostcoNoInd = pd.DataFrame()

# %%
start = time.time()
for TestYear in TestYears:
    TrainYears = list(range(startYear,TestYear))
    trainStDev, testRMSE = iChooseYouPikachu(Costco_Monthly, TrainYears, TestYear, "", 
                                             "", numNodes, SalesColName, includeIndicator)
    currResults = {
        "Train Years": f"[{TrainYears[0]} ... {TrainYears[-1]}]",
        "Pred Year": int(TestYear),
        "Indicator": indicator_file.split("/")[-1],
        "trainStDev": round(trainStDev, 3), 
        "Test RMSE": round(testRMSE, 3),
        "Explained Variance Ratio": round((trainStDev - testRMSE) / trainStDev, 3)
    }
    resultsCostcoNoInd = resultsCostcoNoInd.append(currResults, ignore_index=True)

print("Time elapsed:", time.time()-start)
# Out:
# Time elapsed: 1.8591079711914062

# %%
resultsCostcoNoInd
# Out:
#        Train Years  Pred Year  \
# 0  [2002 ... 2017]     2018.0
# 1  [2002 ... 2018]     2019.0
# 2  [2002 ... 2019]     2020.0
#
#                                            Indicator  trainStDev  Test RMSE  \
# 0  historical_country_United_States_indicator_Gov...       1.555      3.822
# 1  historical_country_United_States_indicator_Gov...       1.811      4.236
# 2  historical_country_United_States_indicator_Gov...       2.062      3.728
#
#    Explained Variance Ratio
# 0                    -1.457
# 1                    -1.339
# 2                    -0.808

# %% [raw]
# resultsCostcoNoInd.to_csv("Results/resultsCostcoNoInd.csv")
# resultsCostcoNoInd.sort_values(by="Explained Variance Ratio").to_csv("Results/resultsCostcoNoInd_sorted.csv")

# %% [markdown]
# ## Maryland Vehicles Dataset

# %%
SalesDataSet = pd.read_pickle('Data/MarylandVehicleSales2002-2021')
SalesDataSet
# Out:
#      Year  Month     New   Used  Total Sales New  Total Sales Used
# 0     2002    JAN  31106  49927        755015820         386481929
# 1     2002    FEB  27520  50982        664454223         361353242
# 2     2002    MAR  34225  58794        805666244         419385387
# 3     2002    APR  36452  59817        846368297         433061150
# 4     2002    MAY  37359  60577        855005784         442569410
# ..     ...    ...    ...    ...              ...               ...
# 227   2020    DEC  28061  44427       1256023978         620534357
# 228   2021    JAN  21674  47934        834312337         622526750
# 229   2021    FEB  20579  42306        797908033         556318165
# 230   2021    MAR  34794  66410       1267127282         848644184
# 231   2021    APR  32730  63931       1213808079         863507284
#
# [232 rows x 6 columns]

# %%
#IndexColumnOfIndicator = 2 #which index is your indicator columns #3
SalesColumnName = 'New' # specify your sales column. New is my sales in this case #4
TestYears = [2018, 2019, 2020] #5
NumNodes = 153 # approx 2/3 of the number of your rows. Make this divisible by a three #6
startYear = 2002 # 7
endYear = 2021 # 8
startMonth = 1 # 9
endMonth = 4 # 10

# %% [markdown]
# # With Indicators

# %%
includeIndicators = True
resultsVehicles = pd.DataFrame()

# %%
start = time.time()
for i, indicator_file in enumerate(glob.glob("Data/Economic indicators/*")):
    print("\n----------\n\n"+indicator_file.split("/")[-1])
    dataframe = SalesDataSet.copy()
    
    IndicatorDataSet = pd.read_csv(indicator_file)
    IndexColumnOfIndicator = indicatorIdxs[i] - 1 # adjust for when DateTime is set as index
    IndicatorDataSetDates = IndicatorDataSet['DateTime']
    IndicatorDataSetDates = IndicatorDataSetDates.apply(lambda x: x[0:10])
    IndicatorDataSet['DateTime'] = IndicatorDataSetDates
    
    IndicatorDataSet = IndicatorDataSet.set_index('DateTime')
    IndicatorDataSet = IndicatorDataSet.loc['2002-01-30':'2021-04-30']
    IndicatorDataSet.reset_index(drop=True, inplace = True)
    
    for TestYear in TestYears:
        TrainYears = list(range(startYear,TestYear))
        trainStDev, testRMSE = run_pipeline(SalesDataSet, IndicatorDataSet, IndexColumnOfIndicator, 
                                            SalesColumnName, TrainYears, TestYear,
                                            NumNodes, startYear, endYear, startMonth,
                                            endMonth, includeIndicators)
        currResults = {
            "Train Years": f"[{TrainYears[0]} ... {TrainYears[-1]}]",
            "Pred Year": int(TestYear),
            "Indicator": indicator_file.split("/")[-1], 
            "Train StDev": round(trainStDev, 3), 
            "Test RMSE": round(testRMSE, 3),
            "Explained Variance Ratio": round((trainStDev - testRMSE) / trainStDev, 3)
        }
        resultsVehicles = resultsVehicles.append(currResults, ignore_index=True)

print("Time elapsed:", time.time()-start)
# Out:
# ----------
#
# historical_country_United_States_indicator_API_Product_Imports.csv
#      New
# 0  31106
# 1  27520
# 2  34225
# 3  36452
# 4  37359
#      Sales  Year  Month  Indicator
# 0    31106  2002      1     -0.129
# 1    27520  2002      2      0.088
# 2    34225  2002      3     -0.030
# 3    36452  2002      4     -0.217
# 4    37359  2002      5     -0.170
# ..     ...   ...    ...        ...
# 187  29644  2017      8      0.110
# 188  28175  2017      9     -0.524
# 189  27886  2017     10      0.424
# 190  24970  2017     11     -0.171
# 191  24944  2017     12      0.167
#
# [192 rows x 4 columns]
#     Sales  Year  Month  Indicator
# 0   28607  2018      1     -0.070
# 1   21448  2018      2      0.315
# 2   26914  2018      3     -0.087
# 3   26729  2018      4     -0.018
# 4   30967  2018      5     -0.200
# 5   31779  2018      6     -0.201
# 6   30342  2018      7      0.620
# 7   30188  2018      8     -0.291
# 8   27180  2018      9     -0.013
# 9   28879  2018     10     -0.054
# 10  24846  2018     11      0.256
# 11  26350  2018     12      0.023
#      New
# 0  31106
# 1  27520
# 2  34225
# 3  36452
# 4  37359
#      Sales  Year  Month  Indicator
# 0    31106  2002      1     -0.129
# 1    27520  2002      2      0.088
# 2    34225  2002      3     -0.030
# 3    36452  2002      4     -0.217
# 4    37359  2002      5     -0.170
# ..     ...   ...    ...        ...
# 199  30188  2018      8     -0.291
# 200  27180  2018      9     -0.013
# 201  28879  2018     10     -0.054
# 202  24846  2018     11      0.256
# 203  26350  2018     12      0.023
#
# [204 rows x 4 columns]
#     Sales  Year  Month  Indicator
# 0   31090  2019      1     -0.318
# 1   21694  2019      2      0.387
# 2   26485  2019      3     -0.577
# 3   30044  2019      4      0.043
# 4   29396  2019      5      0.141
# 5   29142  2019      6     -0.442
# 6   30821  2019      7      0.642
# 7   28399  2019      8     -0.116
# 8   29591  2019      9     -0.132
# 9   28967  2019     10      0.004
# 10  23573  2019     11      0.151
# 11  24839  2019     12     -0.268
#      New
# 0  31106
# 1  27520
# 2  34225
# 3  36452
# 4  37359
#      Sales  Year  Month  Indicator
# 0    31106  2002      1     -0.129
# 1    27520  2002      2      0.088
# 2    34225  2002      3     -0.030
# 3    36452  2002      4     -0.217
# 4    37359  2002      5     -0.170
# ..     ...   ...    ...        ...
# 211  28399  2019      8     -0.116
# 212  29591  2019      9     -0.132
# 213  28967  2019     10      0.004
# 214  23573  2019     11      0.151
# 215  24839  2019     12     -0.268
#
# [216 rows x 4 columns]
#     Sales  Year  Month  Indicator
# 0   27704  2020      1      0.242
# 1   22344  2020      2      0.003
# 2   23873  2020      3     -0.148
# 3   13700  2020      4      0.351
# 4   14835  2020      5     -0.025
# 5   23704  2020      6     -0.275
# 6   26190  2020      7      0.103
# 7   27372  2020      8     -0.137
# 8   27733  2020      9     -0.091
# 9   24777  2020     10      1.006
# 10  25187  2020     11     -0.659
# 11  28061  2020     12      0.149
#
# ----------
#
# historical_country_United_States_indicator_GDP_From_Manufacturing.csv
#      New
# 0  31106
# 1  27520
# 2  34225
# 3  36452
# 4  37359
#      Sales  Year  Month  Indicator
# 0    31106  2002      1     1867.8
# 1    27520  2002      2     1870.3
# 2    34225  2002      3     1887.0
# 3    36452  2002      4     1926.6
# 4    37359  2002      5     1989.4
# ..     ...   ...    ...        ...
# 187  29644  2017      8        NaN
# 188  28175  2017      9        NaN
# 189  27886  2017     10        NaN
# 190  24970  2017     11        NaN
# 191  24944  2017     12        NaN
#
# [192 rows x 4 columns]
#     Sales  Year  Month  Indicator
# 0   28607  2018      1        NaN
# 1   21448  2018      2        NaN
# 2   26914  2018      3        NaN
# 3   26729  2018      4        NaN
# 4   30967  2018      5        NaN
# 5   31779  2018      6        NaN
# 6   30342  2018      7        NaN
# 7   30188  2018      8        NaN
# 8   27180  2018      9        NaN
# 9   28879  2018     10        NaN
# 10  24846  2018     11        NaN
# 11  26350  2018     12        NaN
#      New
# 0  31106
# 1  27520
# 2  34225
# 3  36452
# 4  37359
#      Sales  Year  Month  Indicator
# 0    31106  2002      1     1867.8
# 1    27520  2002      2     1870.3
# 2    34225  2002      3     1887.0
# 3    36452  2002      4     1926.6
# 4    37359  2002      5     1989.4
# ..     ...   ...    ...        ...
# 199  30188  2018      8        NaN
# 200  27180  2018      9        NaN
# 201  28879  2018     10        NaN
# 202  24846  2018     11        NaN
# 203  26350  2018     12        NaN
#
# [204 rows x 4 columns]
#     Sales  Year  Month  Indicator
# 0   31090  2019      1        NaN
# 1   21694  2019      2        NaN
# 2   26485  2019      3        NaN
# 3   30044  2019      4        NaN
# 4   29396  2019      5        NaN
# 5   29142  2019      6        NaN
# 6   30821  2019      7        NaN
# 7   28399  2019      8        NaN
# 8   29591  2019      9        NaN
# 9   28967  2019     10        NaN
# 10  23573  2019     11        NaN
# 11  24839  2019     12        NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/3945502089.py in <module>
#      16     for TestYear in TestYears:
#      17         TrainYears = list(range(startYear,TestYear))
# ---> 18         trainStDev, testRMSE = run_pipeline(SalesDataSet, IndicatorDataSet, IndexColumnOfIndicator,
#      19                                             SalesColumnName, TrainYears, TestYear,
#      20                                             NumNodes, startYear, endYear, startMonth,
#
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/382973985.py in run_pipeline(data, indicatorData, indexOfIndicator, salesColumn, trainYears, testYear, numNodes, startYear, endYear, startMonth, endMonth, includeIndicator)
#      14         dataNew = dataNew[[salesColumn, "Month", "Year"]]
#      15     #the data now has 3 columns: Sales, Month, Year, indicator (all 0s won't make a difference)
# ---> 16     StDev, testRMSE = train_and_test(dataNew, trainYears, testYear,
#      17                                      indexOfIndicator, indicatorData,
#      18                                      numNodes, salesColumn, includeIndicator)
#
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/2184752599.py in train_and_test(dataframe, trainYears, testYear, indexOfIndicator, indicatorData, numNodes, SalesColName, includeIndicator)
#      89
#      90     # Test results from model using training data
# ---> 91     YPreds = model.predict(XTest)
#      92     try:
#      93         testRMSE = mean_squared_error(YTest, YPreds, squared=False)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1743       callbacks.on_predict_begin()
#    1744       batch_outputs = None
# -> 1745       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1746         with data_handler.catch_stop_iteration():
#    1747           for step in data_handler.steps():
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1195     """Yields `(epoch, tf.data.Iterator)`."""
#    1196     with self._truncate_execution_to_epoch():
# -> 1197       data_iterator = iter(self._dataset)
#    1198       for epoch in range(self._initial_epoch, self._epochs):
#    1199         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     409     if context.executing_eagerly() or ops.inside_function():
#     410       with ops.colocate_with(self._variant_tensor):
# --> 411         return iterator_ops.OwnedIterator(self)
#     412     else:
#     413       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     717               output_types=self._flat_output_types,
#     718               output_shapes=self._flat_output_shapes))
# --> 719       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     720       # Delete the resource when this object is deleted
#     721       self._resource_deleter = IteratorResourceDeleter(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3118   if tld.is_eager:
#    3119     try:
# -> 3120       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3121         _ctx, "MakeIterator", name, dataset, iterator)
#    3122       return _result
#
# KeyboardInterrupt:

# %%
pd.options.display.max_colwidth = 100
resultsVehicles

# %% [raw]
# resultsVehicles.to_csv("Results/resultsVehicles.csv")
# resultsVehicles.sort_values(by="Explained Variance Ratio").to_csv("Results/resultsVehicles_sorted.csv")

# %% [markdown]
# # Without Indicators

# %%
includeIndicators = False
resultsVehiclesNoInd = pd.DataFrame()

# %%
start = time.time()
for TestYear in TestYears:
    TrainYears = list(range(startYear,TestYear))
    trainStDev, testRMSE = train_and_test(SalesDataSet, [], "", 
                             SalesColumnName, TrainYears, TestYear,
                             NumNodes, startYear, endYear, startMonth, endMonth,
                             includeIndicators)
    currResults = {
        "Train Years": f"[{TrainYears[0]} ... {TrainYears[-1]}]",
        "Pred Year": int(TestYear),
        "Train Std": round(trainStDev, 3), 
        "Test RMSE": round(testRMSE, 3),
        "Explained Variance Ratio": round((trainStDev - testRMSE) / trainStDev, 3)
    }
    resultsVehiclesNoInd = resultsVehiclesNoInd.append(currResults, ignore_index=True)

print("Time elapsed:", time.time()-start)

# %%
resultsVehiclesNoInd

# %% [raw]
# resultsVehiclesNoInd.to_csv("Results/resultsVehiclesNoInd.csv")
# resultsVehiclesNoInd.sort_values(by="Explained Variance Ratio").to_csv("Results/resultsVehiclesNoInd_sorted.csv")

# %% [markdown]
# # MRTS Sales Dataset

# %%
mrts_data = pd.read_csv("Data/mrtssales_92-present.csv")
mrts_data['Date'] = mrts_data.iloc[:,0].apply(lambda x: x.replace(".", ""))
mrts_data["Month"] = mrts_data["Date"].apply(lambda x: x[:3].upper()).tolist()
mrts_data["Year"] = mrts_data["Date"].apply(lambda x: x[4:].upper()).tolist()
mrts_data = mrts_data.drop([mrts_data.columns[0],"Date"], axis=1)
mrts_data = mrts_data[:-1] # delete present month
mrts_data["Year"] = mrts_data["Year"].astype(int)
mrts_data["Month"] = mrts_data["Month"].apply(lambda x: months[x])
mrts_data_new = mrts_data[mrts_data["Year"]>=2002]
mrts_data_new
# Out:
#      Retail and food services sales, total  \
# 120                                 255598
# 121                                 253086
# 122                                 285261
# 123                                 284747
# 124                                 300402
# ..                                     ...
# 350                                 633078
# 351                                 625527
# 352                                 643099
# 353                                 635437
# 354                                 634486
#
#      Retail sales and food services excl motor vehicle and parts  \
# 120                                             195033
# 121                                             190149
# 122                                             215490
# 123                                             213955
# 124                                             228248
# ..                                                 ...
# 350                                             486171
# 351                                             481396
# 352                                             500389
# 353                                             498169
# 354                                             500441
#
#      Retail sales and food services excl gasoline stations  \
# 120                                             238094
# 121                                             236382
# 122                                             265428
# 123                                             263641
# 124                                             278174
# ..                                                 ...
# 350                                             586718
# 351                                             578253
# 352                                             592919
# 353                                             584134
# 354                                             580997
#
#      Retail sales and food services excl motor vehicle and parts and gasoline stations  \
# 120                                             177529
# 121                                             173445
# 122                                             195657
# 123                                             192849
# 124                                             206020
# ..                                                 ...
# 350                                             439811
# 351                                             434122
# 352                                             450209
# 353                                             446866
# 354                                             446952
#
#      Retail sales, total  \
# 120               230546
# 121               228084
# 122               257133
# 123               257357
# 124               271682
# ..                   ...
# 350               567933
# 351               558181
# 352               570641
# 353               562929
# 354               558031
#
#      Retail sales, total (excl. motor vehicle and parts dealers)  GAFO(1)  \
# 120                                             169981              63242
# 121                                             165147              64043
# 122                                             187362              73116
# 123                                             186565              69137
# 124                                             199528              74799
# ..                                                 ...                ...
# 350                                             421026             126263
# 351                                             414050             119664
# 352                                             427931             126686
# 353                                             425661             124474
# 354                                             423986             127008
#
#      Motor vehicle and parts dealers  \
# 120                            60565
# 121                            62937
# 122                            69771
# 123                            70792
# 124                            72154
# ..                               ...
# 350                           146907
# 351                           144131
# 352                           142710
# 353                           137268
# 354                           134045
#
#      Automobile and other motor vehicle dealers  Automobile dealers  ...  \
# 120                                       55799               52948  ...
# 121                                       58319               54817  ...
# 122                                       64656               60116  ...
# 123                                       65420               60242  ...
# 124                                       66622               61020  ...
# ..                                          ...                 ...  ...
# 350                                      136709              125144  ...
# 351                                      134233              122215  ...
# 352                                      133232              121429  ...
# 353                                      127542              115655  ...
# 354                                      124297              113575  ...
#
#      Nonstore retailers  Electronic shopping and mail-order houses  \
# 120               15901                                       9912
# 121               14323                                       8925
# 122               15690                                       9670
# 123               15105                                       9684
# 124               15145                                       9713
# ..                  ...                                        ...
# 350               87571                                      77955
# 351               85066                                      76206
# 352               84422                                      76293
# 353               85052                                      77056
# 354               80605                                      72804
#
#      Fuel dealers  Food services and drinking places  Drinking places  \
# 120          2826                              25052           1289.0
# 121          2303                              25002           1274.0
# 122          2197                              28128           1430.0
# 123          1746                              27390           1343.0
# 124          1571                              28720           1405.0
# ..            ...                                ...              ...
# 350          3757                              65145              NaN
# 351          2614                              67346              NaN
# 352          2209                              72458              NaN
# 353          2146                              72508              NaN
# 354          2026                              76455              NaN
#
#      Restaurants and other eating places  Full service restaurants  \
# 120                                21704                   11462.0
# 121                                21637                   11355.0
# 122                                24344                   12630.0
# 123                                23605                   12076.0
# 124                                24811                   12790.0
# ..                                   ...                       ...
# 350                                59882                       NaN
# 351                                61717                       NaN
# 352                                66471                       NaN
# 353                                66346                       NaN
# 354                                70011                       NaN
#
#      Limited service eating places  Month  Year
# 120                          10242      1  2002
# 121                          10282      2  2002
# 122                          11714      3  2002
# 123                          11529      4  2002
# 124                          12021      5  2002
# ..                             ...    ...   ...
# 350                          32616      3  2021
# 351                          33008      4  2021
# 352                          34025      5  2021
# 353                          33892      6  2021
# 354                          35415      7  2021
#
# [235 rows x 67 columns]

# %%
includeIndicators = True
resultsMRTS = pd.DataFrame()

TestYears = [2018, 2019, 2020] #5
NumNodes = 153 # approx 2/3 of the number of your rows. Make this divisible by a three #6
startYear = 2002 # 7
endYear = 2021 # 8
startMonth = 1 # 9
endMonth = 4 # 10

# %%
# Every sales column in the the mrts dataset
for SalesColName in mrts_data.columns:
    # Every indicator
    for i, indicator_file in enumerate(glob.glob("Data/Economic indicators/*")):
        print("\n----------\n\n"+indicator_file.split("/")[-1], SalesColName)

        IndicatorDataSet = pd.read_csv(indicator_file)
        IndexColumnOfIndicator = indicatorIdxs[i] - 1 # adjust for when DateTime is set as index
        IndicatorDataSetDates = IndicatorDataSet['DateTime']
        IndicatorDataSetDates = IndicatorDataSetDates.apply(lambda x: x[0:10])
        IndicatorDataSet['DateTime'] = IndicatorDataSetDates
        IndicatorDataSet = IndicatorDataSet.set_index('DateTime')
        IndicatorDataSet = IndicatorDataSet.loc['2002-01-30':'2021-04-30']
        IndicatorDataSet.reset_index(drop=True, inplace = True)
        start = time.time()
        for testYear in TestYears:
            trainYears = list(range(startYear,TestYear))
            trainStDev, testRMSE = run_pipeline(mrts_data_new, IndicatorDataSet, IndexColumnOfIndicator,
                                                SalesColName, trainYears, testYear, numNodes,
                                                startYear, endYear, startMonth,
                                                endMonth, includeIndicator)
            currResults = {
                "Sales Column": SalesColName,
                "Train Years": f"[{TrainYears[0]} ... {TrainYears[-1]}]",
                "Pred Year": int(TestYear),
                "Train Std": round(trainStDev, 3), 
                "Test RMSE": round(testRMSE, 3),
                "Explained Variance Ratio": round((trainStDev - testRMSE) / trainStDev, 3)
            }
            resultsMRTS = resultsMRTS.append(currResults, ignore_index=True)

    print("Time elapsed:", time.time()-start)
# Out:
# ----------
#
# historical_country_United_States_indicator_API_Product_Imports.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002      0.013  255598
# 121      2  2002     -0.141  253086
# 122      3  2002      0.235  285261
# 123      4  2002     -0.099  284747
# 124      5  2002     -0.053  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      0.013
# 1    253086  2002      2     -0.141
# 2    285261  2002      3      0.235
# 3    284747  2002      4     -0.099
# 4    300402  2002      5     -0.053
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002      0.013  255598
# 121      2  2002     -0.141  253086
# 122      3  2002      0.235  285261
# 123      4  2002     -0.099  284747
# 124      5  2002     -0.053  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      0.013
# 1    253086  2002      2     -0.141
# 2    285261  2002      3      0.235
# 3    284747  2002      4     -0.099
# 4    300402  2002      5     -0.053
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002      0.013  255598
# 121      2  2002     -0.141  253086
# 122      3  2002      0.235  285261
# 123      4  2002     -0.099  284747
# 124      5  2002     -0.053  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      0.013
# 1    253086  2002      2     -0.141
# 2    285261  2002      3      0.235
# 3    284747  2002      4     -0.099
# 4    300402  2002      5     -0.053
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
#
# ----------
#
# historical_country_United_States_indicator_GDP_From_Manufacturing.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
# ----------
#
# historical_country_United_States_indicator_Private_Debt_to_GDP.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
#
# ----------
#
# historical_country_United_States_indicator_Pending_Home_Sales.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        9.0  255598
# 121      2  2002       11.1  253086
# 122      3  2002       12.3  285261
# 123      4  2002       15.8  284747
# 124      5  2002       11.5  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        9.0
# 1    253086  2002      2       11.1
# 2    285261  2002      3       12.3
# 3    284747  2002      4       15.8
# 4    300402  2002      5       11.5
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        9.0  255598
# 121      2  2002       11.1  253086
# 122      3  2002       12.3  285261
# 123      4  2002       15.8  284747
# 124      5  2002       11.5  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        9.0
# 1    253086  2002      2       11.1
# 2    285261  2002      3       12.3
# 3    284747  2002      4       15.8
# 4    300402  2002      5       11.5
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        9.0  255598
# 121      2  2002       11.1  253086
# 122      3  2002       12.3  285261
# 123      4  2002       15.8  284747
# 124      5  2002       11.5  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        9.0
# 1    253086  2002      2       11.1
# 2    285261  2002      3       12.3
# 3    284747  2002      4       15.8
# 4    300402  2002      5       11.5
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
# ----------
#
# historical_country_United_States_indicator_Crude_Oil_Rigs.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        153  255598
# 121      2  2002        156  253086
# 122      3  2002        159  285261
# 123      4  2002        162  284747
# 124      5  2002        163  300402
# ..     ...   ...        ...     ...
# 350      3  2021        428  633078
# 351      4  2021        423  625527
# 352      5  2021        408  643099
# 353      6  2021        442  635437
# 354      7  2021        429  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        153
# 1    253086  2002      2        156
# 2    285261  2002      3        159
# 3    284747  2002      4        162
# 4    300402  2002      5        163
# ..      ...   ...    ...        ...
# 199  520544  2018      8        343
# 200  477137  2018      9        341
# 201  503602  2018     10        350
# 202  518457  2018     11        362
# 203  556614  2018     12        355
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        318
# 1   435373  2018      2        324
# 2   508383  2018      3        324
# 3   480373  2018      4        339
# 4   527991  2018      5        333
# 5   507106  2018      6        337
# 6   505209  2018      7        337
# 7   520544  2018      8        343
# 8   477137  2018      9        341
# 9   503602  2018     10        350
# 10  518457  2018     11        362
# 11  556614  2018     12        355
#      Month  Year  Indicator   Sales
# 120      1  2002        153  255598
# 121      2  2002        156  253086
# 122      3  2002        159  285261
# 123      4  2002        162  284747
# 124      5  2002        163  300402
# ..     ...   ...        ...     ...
# 350      3  2021        428  633078
# 351      4  2021        423  625527
# 352      5  2021        408  643099
# 353      6  2021        442  635437
# 354      7  2021        429  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        153
# 1    253086  2002      2        156
# 2    285261  2002      3        159
# 3    284747  2002      4        162
# 4    300402  2002      5        163
# ..      ...   ...    ...        ...
# 199  520544  2018      8        343
# 200  477137  2018      9        341
# 201  503602  2018     10        350
# 202  518457  2018     11        362
# 203  556614  2018     12        355
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        355
# 1   442274  2019      2        360
# 2   513845  2019      3        357
# 3   506920  2019      4        361
# 4   544203  2019      5        381
# 5   515269  2019      6        386
# 6   528710  2019      7        390
# 7   541951  2019      8        385
# 8   493076  2019      9        389
# 9   522195  2019     10        384
# 10  532130  2019     11        375
# 11  587471  2019     12        373
#      Month  Year  Indicator   Sales
# 120      1  2002        153  255598
# 121      2  2002        156  253086
# 122      3  2002        159  285261
# 123      4  2002        162  284747
# 124      5  2002        163  300402
# ..     ...   ...        ...     ...
# 350      3  2021        428  633078
# 351      4  2021        423  625527
# 352      5  2021        408  643099
# 353      6  2021        442  635437
# 354      7  2021        429  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        153
# 1    253086  2002      2        156
# 2    285261  2002      3        159
# 3    284747  2002      4        162
# 4    300402  2002      5        163
# ..      ...   ...    ...        ...
# 199  520544  2018      8        343
# 200  477137  2018      9        341
# 201  503602  2018     10        350
# 202  518457  2018     11        362
# 203  556614  2018     12        355
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        370
# 1   478467  2020      2        385
# 2   478267  2020      3        393
# 3   407227  2020      4        392
# 4   504607  2020      5        387
# 5   532678  2020      6        395
# 6   549416  2020      7        395
# 7   545307  2020      8        416
# 8   530987  2020      9        416
# 9   553114  2020     10        413
# 10  543273  2020     11        417
# 11  611429  2020     12        423
#
# ----------
#
# historical_country_United_States_indicator_Crude_Oil_Imports.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        561  255598
# 121      2  2002        210  253086
# 122      3  2002       -220  285261
# 123      4  2002       -212  284747
# 124      5  2002        -83  300402
# ..     ...   ...        ...     ...
# 350      3  2021        239  633078
# 351      4  2021        -63  625527
# 352      5  2021       -365  643099
# 353      6  2021       -469  635437
# 354      7  2021        368  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        561
# 1    253086  2002      2        210
# 2    285261  2002      3       -220
# 3    284747  2002      4       -212
# 4    300402  2002      5        -83
# ..      ...   ...    ...        ...
# 199  520544  2018      8      -1080
# 200  477137  2018      9       -570
# 201  503602  2018     10       1385
# 202  518457  2018     11      -1371
# 203  556614  2018     12        -33
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1       -100
# 1   435373  2018      2        458
# 2   508383  2018      3       -777
# 3   480373  2018      4        365
# 4   527991  2018      5       -144
# 5   507106  2018      6       -521
# 6   505209  2018      7       1111
# 7   520544  2018      8      -1080
# 8   477137  2018      9       -570
# 9   503602  2018     10       1385
# 10  518457  2018     11      -1371
# 11  556614  2018     12        -33
#      Month  Year  Indicator   Sales
# 120      1  2002        561  255598
# 121      2  2002        210  253086
# 122      3  2002       -220  285261
# 123      4  2002       -212  284747
# 124      5  2002        -83  300402
# ..     ...   ...        ...     ...
# 350      3  2021        239  633078
# 351      4  2021        -63  625527
# 352      5  2021       -365  643099
# 353      6  2021       -469  635437
# 354      7  2021        368  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        561
# 1    253086  2002      2        210
# 2    285261  2002      3       -220
# 3    284747  2002      4       -212
# 4    300402  2002      5        -83
# ..      ...   ...    ...        ...
# 199  520544  2018      8      -1080
# 200  477137  2018      9       -570
# 201  503602  2018     10       1385
# 202  518457  2018     11      -1371
# 203  556614  2018     12        -33
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1       1162
# 1   442274  2019      2        174
# 2   513845  2019      3        413
# 3   506920  2019      4       -695
# 4   544203  2019      5       -696
# 5   515269  2019      6       -278
# 6   528710  2019      7        826
# 7   541951  2019      8        -98
# 8   493076  2019      9        571
# 9   522195  2019     10         -8
# 10  532130  2019     11        -83
# 11  587471  2019     12       -621
#      Month  Year  Indicator   Sales
# 120      1  2002        561  255598
# 121      2  2002        210  253086
# 122      3  2002       -220  285261
# 123      4  2002       -212  284747
# 124      5  2002        -83  300402
# ..     ...   ...        ...     ...
# 350      3  2021        239  633078
# 351      4  2021        -63  625527
# 352      5  2021       -365  643099
# 353      6  2021       -469  635437
# 354      7  2021        368  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        561
# 1    253086  2002      2        210
# 2    285261  2002      3       -220
# 3    284747  2002      4       -212
# 4    300402  2002      5        -83
# ..      ...   ...    ...        ...
# 199  520544  2018      8      -1080
# 200  477137  2018      9       -570
# 201  503602  2018     10       1385
# 202  518457  2018     11      -1371
# 203  556614  2018     12        -33
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1       1244
# 1   478467  2020      2       -985
# 2   478267  2020      3        199
# 3   407227  2020      4        188
# 4   504607  2020      5       -538
# 5   532678  2020      6       1336
# 6   549416  2020      7      -1012
# 7   545307  2020      8       -148
# 8   530987  2020      9      -1249
# 9   553114  2020     10        -71
# 10  543273  2020     11      -1367
# 11  611429  2020     12       1846
# ----------
#
# historical_country_United_States_indicator_Wages_in_Manufacturing.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002      19.10  255598
# 121      2  2002      19.03  253086
# 122      3  2002      19.02  285261
# 123      4  2002      19.14  284747
# 124      5  2002      19.01  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      19.10
# 1    253086  2002      2      19.03
# 2    285261  2002      3      19.02
# 3    284747  2002      4      19.14
# 4    300402  2002      5      19.01
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002      19.10  255598
# 121      2  2002      19.03  253086
# 122      3  2002      19.02  285261
# 123      4  2002      19.14  284747
# 124      5  2002      19.01  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      19.10
# 1    253086  2002      2      19.03
# 2    285261  2002      3      19.02
# 3    284747  2002      4      19.14
# 4    300402  2002      5      19.01
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002      19.10  255598
# 121      2  2002      19.03  253086
# 122      3  2002      19.02  285261
# 123      4  2002      19.14  284747
# 124      5  2002      19.01  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      19.10
# 1    253086  2002      2      19.03
# 2    285261  2002      3      19.02
# 3    284747  2002      4      19.14
# 4    300402  2002      5      19.01
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
#
# ----------
#
# historical_country_United_States_indicator_Balance_of_Trade.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002   -50126.0  255598
# 121      2  2002   -42780.0  253086
# 122      3  2002   -49749.0  285261
# 123      4  2002   -46842.0  284747
# 124      5  2002   -45106.0  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1   -50126.0
# 1    253086  2002      2   -42780.0
# 2    285261  2002      3   -49749.0
# 3    284747  2002      4   -46842.0
# 4    300402  2002      5   -45106.0
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002   -50126.0  255598
# 121      2  2002   -42780.0  253086
# 122      3  2002   -49749.0  285261
# 123      4  2002   -46842.0  284747
# 124      5  2002   -45106.0  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1   -50126.0
# 1    253086  2002      2   -42780.0
# 2    285261  2002      3   -49749.0
# 3    284747  2002      4   -46842.0
# 4    300402  2002      5   -45106.0
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002   -50126.0  255598
# 121      2  2002   -42780.0  253086
# 122      3  2002   -49749.0  285261
# 123      4  2002   -46842.0  284747
# 124      5  2002   -45106.0  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1   -50126.0
# 1    253086  2002      2   -42780.0
# 2    285261  2002      3   -49749.0
# 3    284747  2002      4   -46842.0
# 4    300402  2002      5   -45106.0
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
# ----------
#
# historical_country_United_States_indicator_Wage_Growth.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002       3.47  255598
# 121      2  2002       3.97  253086
# 122      3  2002       4.35  285261
# 123      4  2002       4.48  284747
# 124      5  2002       3.98  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1       3.47
# 1    253086  2002      2       3.97
# 2    285261  2002      3       4.35
# 3    284747  2002      4       4.48
# 4    300402  2002      5       3.98
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002       3.47  255598
# 121      2  2002       3.97  253086
# 122      3  2002       4.35  285261
# 123      4  2002       4.48  284747
# 124      5  2002       3.98  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1       3.47
# 1    253086  2002      2       3.97
# 2    285261  2002      3       4.35
# 3    284747  2002      4       4.48
# 4    300402  2002      5       3.98
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002       3.47  255598
# 121      2  2002       3.97  253086
# 122      3  2002       4.35  285261
# 123      4  2002       4.48  284747
# 124      5  2002       3.98  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1       3.47
# 1    253086  2002      2       3.97
# 2    285261  2002      3       4.35
# 3    284747  2002      4       4.48
# 4    300402  2002      5       3.98
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
#
# ----------
#
# historical_country_United_States_indicator_Net_Long_Term_Tic_Flows.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002   112127.0  255598
# 121      2  2002     7584.0  253086
# 122      3  2002    36638.0  285261
# 123      4  2002    41276.0  284747
# 124      5  2002    90573.0  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1   112127.0
# 1    253086  2002      2     7584.0
# 2    285261  2002      3    36638.0
# 3    284747  2002      4    41276.0
# 4    300402  2002      5    90573.0
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002   112127.0  255598
# 121      2  2002     7584.0  253086
# 122      3  2002    36638.0  285261
# 123      4  2002    41276.0  284747
# 124      5  2002    90573.0  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1   112127.0
# 1    253086  2002      2     7584.0
# 2    285261  2002      3    36638.0
# 3    284747  2002      4    41276.0
# 4    300402  2002      5    90573.0
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002   112127.0  255598
# 121      2  2002     7584.0  253086
# 122      3  2002    36638.0  285261
# 123      4  2002    41276.0  284747
# 124      5  2002    90573.0  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1   112127.0
# 1    253086  2002      2     7584.0
# 2    285261  2002      3    36638.0
# 3    284747  2002      4    41276.0
# 4    300402  2002      5    90573.0
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
# ----------
#
# historical_country_United_States_indicator_GDP.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        NaN  255598
# 121      2  2002        NaN  253086
# 122      3  2002        NaN  285261
# 123      4  2002        NaN  284747
# 124      5  2002        NaN  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        NaN
# 1    253086  2002      2        NaN
# 2    285261  2002      3        NaN
# 3    284747  2002      4        NaN
# 4    300402  2002      5        NaN
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
#
# ----------
#
# historical_country_United_States_indicator_Core_Producer_Prices.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002      117.9  255598
# 121      2  2002      117.9  253086
# 122      3  2002      118.2  285261
# 123      4  2002      118.7  284747
# 124      5  2002      118.9  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1      117.9
# 1    253086  2002      2      117.9
# 2    285261  2002      3      118.2
# 3    284747  2002      4      118.7
# 4    300402  2002      5      118.9
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002      117.9  255598
# 121      2  2002      117.9  253086
# ...
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        0.3
# 1    253086  2002      2        0.2
# 2    285261  2002      3        0.2
# 3    284747  2002      4        0.2
# 4    300402  2002      5        0.1
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
#
# ----------
#
# historical_country_United_States_indicator_Retail_Sales_MoM.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        1.1  255598
# 121      2  2002        1.2  253086
# 122      3  2002        0.3  285261
# 123      4  2002       -0.4  284747
# 124      5  2002       -0.2  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        1.1
# 1    253086  2002      2        1.2
# 2    285261  2002      3        0.3
# 3    284747  2002      4       -0.4
# 4    300402  2002      5       -0.2
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        NaN
# 1   435373  2018      2        NaN
# 2   508383  2018      3        NaN
# 3   480373  2018      4        NaN
# 4   527991  2018      5        NaN
# 5   507106  2018      6        NaN
# 6   505209  2018      7        NaN
# 7   520544  2018      8        NaN
# 8   477137  2018      9        NaN
# 9   503602  2018     10        NaN
# 10  518457  2018     11        NaN
# 11  556614  2018     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        1.1  255598
# 121      2  2002        1.2  253086
# 122      3  2002        0.3  285261
# 123      4  2002       -0.4  284747
# 124      5  2002       -0.2  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        1.1
# 1    253086  2002      2        1.2
# 2    285261  2002      3        0.3
# 3    284747  2002      4       -0.4
# 4    300402  2002      5       -0.2
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        NaN
# 1   442274  2019      2        NaN
# 2   513845  2019      3        NaN
# 3   506920  2019      4        NaN
# 4   544203  2019      5        NaN
# 5   515269  2019      6        NaN
# 6   528710  2019      7        NaN
# 7   541951  2019      8        NaN
# 8   493076  2019      9        NaN
# 9   522195  2019     10        NaN
# 10  532130  2019     11        NaN
# 11  587471  2019     12        NaN
#      Month  Year  Indicator   Sales
# 120      1  2002        1.1  255598
# 121      2  2002        1.2  253086
# 122      3  2002        0.3  285261
# 123      4  2002       -0.4  284747
# 124      5  2002       -0.2  300402
# ..     ...   ...        ...     ...
# 350      3  2021        NaN  633078
# 351      4  2021        NaN  625527
# 352      5  2021        NaN  643099
# 353      6  2021        NaN  635437
# 354      7  2021        NaN  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        1.1
# 1    253086  2002      2        1.2
# 2    285261  2002      3        0.3
# 3    284747  2002      4       -0.4
# 4    300402  2002      5       -0.2
# ..      ...   ...    ...        ...
# 199  520544  2018      8        NaN
# 200  477137  2018      9        NaN
# 201  503602  2018     10        NaN
# 202  518457  2018     11        NaN
# 203  556614  2018     12        NaN
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        NaN
# 1   478467  2020      2        NaN
# 2   478267  2020      3        NaN
# 3   407227  2020      4        NaN
# 4   504607  2020      5        NaN
# 5   532678  2020      6        NaN
# 6   549416  2020      7        NaN
# 7   545307  2020      8        NaN
# 8   530987  2020      9        NaN
# 9   553114  2020     10        NaN
# 10  543273  2020     11        NaN
# 11  611429  2020     12        NaN
# ----------
#
# historical_country_United_States_indicator_Redbook_Index.csv Retail and food services sales, total
#      Month  Year  Indicator   Sales
# 120      1  2002        2.4  255598
# 121      2  2002        1.8  253086
# 122      3  2002        1.7  285261
# 123      4  2002        2.0  284747
# 124      5  2002        1.4  300402
# ..     ...   ...        ...     ...
# 350      3  2021        4.1  633078
# 351      4  2021        5.2  625527
# 352      5  2021        3.1  643099
# 353      6  2021        3.3  635437
# 354      7  2021        3.7  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        2.4
# 1    253086  2002      2        1.8
# 2    285261  2002      3        1.7
# 3    284747  2002      4        2.0
# 4    300402  2002      5        1.4
# ..      ...   ...    ...        ...
# 199  520544  2018      8        2.4
# 200  477137  2018      9        2.6
# 201  503602  2018     10        0.5
# 202  518457  2018     11        4.7
# 203  556614  2018     12        5.1
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   444286  2018      1        1.8
# 1   435373  2018      2        2.7
# 2   508383  2018      3        2.2
# 3   480373  2018      4        2.7
# 4   527991  2018      5        3.0
# 5   507106  2018      6        2.0
# 6   505209  2018      7        2.0
# 7   520544  2018      8        2.4
# 8   477137  2018      9        2.6
# 9   503602  2018     10        0.5
# 10  518457  2018     11        4.7
# 11  556614  2018     12        5.1
#      Month  Year  Indicator   Sales
# 120      1  2002        2.4  255598
# 121      2  2002        1.8  253086
# 122      3  2002        1.7  285261
# 123      4  2002        2.0  284747
# 124      5  2002        1.4  300402
# ..     ...   ...        ...     ...
# 350      3  2021        4.1  633078
# 351      4  2021        5.2  625527
# 352      5  2021        3.1  643099
# 353      6  2021        3.3  635437
# 354      7  2021        3.7  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        2.4
# 1    253086  2002      2        1.8
# 2    285261  2002      3        1.7
# 3    284747  2002      4        2.0
# 4    300402  2002      5        1.4
# ..      ...   ...    ...        ...
# 199  520544  2018      8        2.4
# 200  477137  2018      9        2.6
# 201  503602  2018     10        0.5
# 202  518457  2018     11        4.7
# 203  556614  2018     12        5.1
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   456538  2019      1        5.3
# 1   442274  2019      2        5.5
# 2   513845  2019      3        4.7
# 3   506920  2019      4        4.0
# 4   544203  2019      5        3.4
# 5   515269  2019      6        3.6
# 6   528710  2019      7        4.2
# 7   541951  2019      8        3.2
# 8   493076  2019      9        4.2
# 9   522195  2019     10        2.5
# 10  532130  2019     11        5.2
# 11  587471  2019     12        5.4
#      Month  Year  Indicator   Sales
# 120      1  2002        2.4  255598
# 121      2  2002        1.8  253086
# 122      3  2002        1.7  285261
# 123      4  2002        2.0  284747
# 124      5  2002        1.4  300402
# ..     ...   ...        ...     ...
# 350      3  2021        4.1  633078
# 351      4  2021        5.2  625527
# 352      5  2021        3.1  643099
# 353      6  2021        3.3  635437
# 354      7  2021        3.7  634486
#
# [235 rows x 4 columns]
#       Sales  Year  Month  Indicator
# 0    255598  2002      1        2.4
# 1    253086  2002      2        1.8
# 2    285261  2002      3        1.7
# 3    284747  2002      4        2.0
# 4    300402  2002      5        1.4
# ..      ...   ...    ...        ...
# 199  520544  2018      8        2.4
# 200  477137  2018      9        2.6
# 201  503602  2018     10        0.5
# 202  518457  2018     11        4.7
# 203  556614  2018     12        5.1
#
# [204 rows x 4 columns]
#      Sales  Year  Month  Indicator
# 0   480301  2020      1        3.8
# 1   478467  2020      2        3.5
# 2   478267  2020      3        4.5
# 3   407227  2020      4        4.8
# 4   504607  2020      5        4.7
# 5   532678  2020      6        3.3
# 6   549416  2020      7        4.0
# 7   545307  2020      8        4.9
# 8   530987  2020      9        4.5
# 9   553114  2020     10        4.1
# 10  543273  2020     11        4.2
# 11  611429  2020     12        4.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/2417282430.py in <module>
#      16         for testYear in TestYears:
#      17             trainYears = list(range(startYear,TestYear))
# ---> 18             trainStDev, testRMSE = run_pipeline(mrts_data_new, IndicatorDataSet, IndexColumnOfIndicator,
#      19                                                 SalesColName, trainYears, testYear, numNodes,
#      20                                                 startYear, endYear, startMonth,
#
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/382973985.py in run_pipeline(data, indicatorData, indexOfIndicator, salesColumn, trainYears, testYear, numNodes, startYear, endYear, startMonth, endMonth, includeIndicator)
#      14         dataNew = dataNew[[salesColumn, "Month", "Year"]]
#      15     #the data now has 3 columns: Sales, Month, Year, indicator (all 0s won't make a difference)
# ---> 16     StDev, testRMSE = train_and_test(dataNew, trainYears, testYear,
#      17                                      indexOfIndicator, indicatorData,
#      18                                      numNodes, salesColumn, includeIndicator)
#
# /var/folders/6c/x9kp6vcn1fbbls1jmdmp3ylm0000gn/T/ipykernel_80534/2086805705.py in train_and_test(dataframe, trainYears, testYear, indexOfIndicator, indicatorData, numNodes, SalesColName, includeIndicator)
#      87     # Create and Fit Model
#      88     model = create_model(numNodes, includeIndicator)
# ---> 89     model.fit(XTrain, YTrain, epochs=100, batch_size=128, verbose=0) #change batch size to a variable
#      90
#      91     # Test results from model using training data
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1191                 _r=1):
#    1192               callbacks.on_train_batch_begin(step)
# -> 1193               tmp_logs = self.train_function(iterator)
#    1194               if data_handler.should_sync:
#    1195                 context.async_wait()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3036     with self._lock:
#    3037       (graph_function,
# -> 3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1046         if x is not None)
#    1047
# -> 1048     func_graph.variables = variables
#    1049
#    1050   if add_control_dependencies:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     385           (op_is_stateful(op) and
#     386            (op.type not in utils.RESOURCE_READ_OPS or
# --> 387             any(output.consumers() for output in op.outputs)))):
#     388         ops_which_must_run.add(op)
#     389       # Make a note of all opened manager_ids.
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/framework/auto_control_deps.py in <genexpr>(.0)
#     385           (op_is_stateful(op) and
#     386            (op.type not in utils.RESOURCE_READ_OPS or
# --> 387             any(output.consumers() for output in op.outputs)))):
#     388         ops_which_must_run.add(op)
#     389       # Make a note of all opened manager_ids.
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in consumers(self)
#     791         self._as_tf_output())
#     792     # pylint: disable=protected-access
# --> 793     return [
#     794         self.graph._get_operation_by_name_unsafe(name)
#     795         for name in consumer_names
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in <listcomp>(.0)
#     792     # pylint: disable=protected-access
#     793     return [
# --> 794         self.graph._get_operation_by_name_unsafe(name)
#     795         for name in consumer_names
#     796     ]
#
# KeyboardInterrupt:
